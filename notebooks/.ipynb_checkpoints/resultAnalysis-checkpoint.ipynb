# %%
import os
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
plt.rcParams["figure.figsize"] = (20,20)

# %%
path = os.getcwd()

# %%
def readPickle(datapath):
    objects = []
    with (open(datapath, "rb")) as openfile:
        while True:
            try:
                objects.append(pickle.load(openfile))
            except EOFError:
                break
    return objects

# %%
datapath = os.path.join(path, "../../results/agentList.pkl")
with open(datapath, 'rb') as f:
    agentList = pickle.load(f)

# %%
datapath = os.path.join(path, "../../results/returns.pkl")
objects = readPickle(datapath)
returns = []
for obj in objects:
    returns = returns + obj

# %%
datapath = os.path.join(path, "../../results/loss.pkl")
objects = readPickle(datapath)
loss = []
for obj in objects:
    loss = loss + obj

# %%
datapath = os.path.join(path, "../../results/congestionStatus.pkl")
objects = []
with (open(datapath, "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break
congestionStatus = pd.concat(objects, axis=0, ignore_index=False)

# %%
congestionStatus
# Out:
#       Trafo_HSMS  Trafo_HSMS_par  L_Knoten_17_Stichabgang_R_Knoten_HSMS_MS  \
# 8256       False           False                                     False
# 8257       False           False                                     False
# 8258       False           False                                     False
# 8259       False           False                                     False
# 8260       False           False                                     False
# ...          ...             ...                                       ...
# 8515       False           False                                     False
# 8516       False           False                                     False
# 8517       False           False                                     False
# 8518       False           False                                     False
# 8519       False           False                                     False
#
#       Knoten_17_Stich  L_65R_39  Trafo_65  L_52R_39  L_24R_39  Trafo_24  \
# 8256            False     False     False     False     False     False
# 8257            False     False     False     False     False     False
# 8258            False     False     False     False     False     False
# 8259            False     False     False     False     False     False
# 8260            False     False     False     False     False     False
# ...               ...       ...       ...       ...       ...       ...
# 8515            False     False     False     False     False     False
# 8516            False     False     False     False     False     False
# 8517            False     False     False     False     False     False
# 8518            False     False     False     False     False     False
# 8519            False     False     False     False     False     False
#
#       L_Knoten_127_Stichabgang_R_Knoten_24  ...  Knoten_40_Stich  \
# 8256                                 False  ...            False
# 8257                                 False  ...            False
# 8258                                 False  ...            False
# 8259                                 False  ...            False
# 8260                                 False  ...            False
# ...                                    ...  ...              ...
# 8515                                 False  ...            False
# 8516                                 False  ...            False
# 8517                                 False  ...            False
# 8518                                 False  ...            False
# 8519                                 False  ...            False
#
#       L_Knoten_40_Stichabgang_R_Knoten_72  L_72R_36  Trafo_49  L_36R_36  \
# 8256                                False     False     False     False
# 8257                                False     False     False     False
# 8258                                False     False     False     False
# 8259                                False     False     False     False
# 8260                                False     False     False     False
# ...                                   ...       ...       ...       ...
# 8515                                False     False     False     False
# 8516                                False     False     False     False
# 8517                                False     False     False     False
# 8518                                False     False     False     False
# 8519                                False     False     False     False
#
#       Trafo_36  L_Knoten_18_Stichabgang_R_Knoten_72_boost  \
# 8256     False                                      False
# 8257     False                                      False
# 8258     False                                      False
# 8259     False                                      False
# 8260     False                                      False
# ...        ...                                        ...
# 8515     False                                      False
# 8516     False                                      False
# 8517     False                                      False
# 8518     False                                      False
# 8519     False                                      False
#
#       L_Knoten_25_Stichabgang_R_Knoten_18_Stichabgang_boost  L_0R_36_boost  \
# 8256                                              False              False
# 8257                                              False              False
# 8258                                              False              False
# 8259                                              False              False
# 8260                                              False              False
# ...                                                 ...                ...
# 8515                                              False              False
# 8516                                              False              False
# 8517                                              False              False
# 8518                                              False              False
# 8519                                              False              False
#
#       L_0R_36_boost_1
# 8256            False
# 8257            False
# 8258            False
# 8259            False
# 8260            False
# ...               ...
# 8515            False
# 8516            False
# 8517            False
# 8518            False
# 8519            False
#
# [960 rows x 217 columns]

# %%
num_iterations = 1000
eval_interval = 20
log_interval = 10
ret_steps = range(0, num_iterations + 1, eval_interval)
loss_steps = range(0, num_iterations, log_interval)

# %%
fig, axs = plt.subplots(3, 2)
i = 0
for j in range(3):
    for k in range(2):
        agent_returns = [ret[i] for ret in returns]
        axs[j, k].plot(ret_steps, agent_returns, 'tab:green')
        axs[j, k].set(ylabel='Avg Return - {}'.format(agentList[i]), xlabel='Step')
        i += 1

# %%
fig, axs = plt.subplots(3, 2)
i = 0
for j in range(3):
    for k in range(2):
        agent_loss = [l[i] for l in loss]
        axs[j, k].plot(loss_steps, agent_loss, 'tab:red')
        axs[j, k].set(ylabel='Loss - {}'.format(agentList[i]), xlabel='Step')
        i += 1

# %%
congestionSeries = congestionStatus.sum(axis=1).values
plt.plot(range(0,len(congestionSeries)), congestionSeries)
